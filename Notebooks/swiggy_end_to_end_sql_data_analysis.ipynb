# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:root@localhost

# %%
# %%sql
# CREATE DATABASE IF NOT EXISTS swiggy_da;
# USE swiggy_da;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# # CREATING TABLES WHICH NEEDED
# CREATE TABLE users (
#     user_id INT AUTO_INCREMENT PRIMARY KEY,
#     location_area VARCHAR(50) NOT NULL,
#     created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'users' already exists
# [SQL: CREATE TABLE users (
#     user_id INT AUTO_INCREMENT PRIMARY KEY,
#     location_area VARCHAR(50) NOT NULL,
#     created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# CREATE TABLE restaurants (
#     restaurant_id INT AUTO_INCREMENT PRIMARY KEY,
#     name VARCHAR(100) NOT NULL,
#     cuisine VARCHAR(100) NOT NULL,
#     is_veg BOOLEAN NOT NULL,
#     price_for_two INT NOT NULL,
#     rating DECIMAL(2,1) CHECK (rating BETWEEN 0 AND 5)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE menu_items (
#     item_id INT AUTO_INCREMENT PRIMARY KEY,
#     restaurant_id INT NOT NULL,
#     item_name VARCHAR(100) NOT NULL,
#     price INT NOT NULL,
#     category VARCHAR(50),
#     is_veg BOOLEAN NOT NULL,
#     CONSTRAINT fk_menu_restaurant
#         FOREIGN KEY (restaurant_id)
#         REFERENCES restaurants(restaurant_id)
#         ON DELETE CASCADE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE orders (
#     order_id INT AUTO_INCREMENT PRIMARY KEY,
#     user_id INT NOT NULL,
#     restaurant_id INT NOT NULL,
#     order_time DATETIME NOT NULL,
#     total_amount INT NOT NULL,
#     order_status VARCHAR(30) NOT NULL,
#     CONSTRAINT fk_orders_user
#         FOREIGN KEY (user_id)
#         REFERENCES users(user_id),
#     CONSTRAINT fk_orders_restaurant
#         FOREIGN KEY (restaurant_id)
#         REFERENCES restaurants(restaurant_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE order_items (
#     order_item_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT NOT NULL,
#     item_id INT NOT NULL,
#     quantity INT NOT NULL CHECK (quantity > 0),
#     item_price INT NOT NULL,
#     CONSTRAINT fk_orderitems_order
#         FOREIGN KEY (order_id)
#         REFERENCES orders(order_id)
#         ON DELETE CASCADE,
#     CONSTRAINT fk_orderitems_item
#         FOREIGN KEY (item_id)
#         REFERENCES menu_items(item_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE deliveries (
#     delivery_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT NOT NULL,
#     expected_minutes INT NOT NULL,
#     actual_minutes INT NOT NULL,
#     delivery_status VARCHAR(30) NOT NULL,
#     CONSTRAINT fk_delivery_order
#         FOREIGN KEY (order_id)
#         REFERENCES orders(order_id)
#         ON DELETE CASCADE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE reviews (
#     review_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT NOT NULL UNIQUE,
#     rating INT CHECK (rating BETWEEN 1 AND 5),
#     review_time DATETIME NOT NULL,
#     CONSTRAINT fk_reviews_order
#         FOREIGN KEY (order_id)
#         REFERENCES orders(order_id)
#         ON DELETE CASCADE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# # ADDED A USER 1 MANUALLY FOR TESTING THE API
# INSERT INTO users (location_area)
# VALUES ('South Delhi');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM users;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(1, 'South Delhi', datetime.datetime(2026, 1, 15, 12, 24, 4))]

# %%
# %%sql
# # AND ALSO INSERTED SOME RESTAURENT AND MENU_ITEMS
# INSERT INTO restaurants (name, cuisine, is_veg, price_for_two, rating)
# VALUES ('Spicy Hub', 'North Indian', FALSE, 500, 4.3);
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# select * from restaurants
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(1, 'Spicy Hub', 'North Indian', 0, 500, Decimal('4.3'))]

# %%
# %%sql
# INSERT INTO menu_items (restaurant_id, item_name, price, category, is_veg)
# VALUES
# (1, 'Chicken Biryani', 250, 'Main Course', FALSE),
# (1, 'Paneer Butter Masala', 220, 'Main Course', TRUE);
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# []

# %%
# %%sql
# select * from menu_items
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(1, 1, 'Chicken Biryani', 250, 'Main Course', 0),
#  (2, 1, 'Paneer Butter Masala', 220, 'Main Course', 1)]

# %%
# %%sql
# # WHAT WE DID HERE IS USED API TO GET DATA FROM FRONT END AND IT WORKED AND WE HAVE DATA HERE
# SELECT * FROM orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(10, 1, 1, datetime.datetime(2026, 1, 15, 12, 27, 42), 470, 'CONFIRMED')]

# %%
# %%sql
# SELECT * FROM order_items;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(2, 10, 1, 1, 250), (3, 10, 2, 1, 220)]

# %%
# %%sql
# SELECT * FROM deliveries;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4080 rows affected.
# [(1, 10, 30, 25, 'DELIVERED'),
#  (2, 18, 31, 26, 'DELIVERED'),
#  (3, 19, 23, 18, 'DELIVERED'),
#  (4, 20, 23, 33, 'DELIVERED'),
#  (5, 21, 35, 35, 'DELIVERED'),
#  (6, 22, 32, 32, 'DELIVERED'),
#  (7, 23, 33, 28, 'DELIVERED'),
#  (8, 24, 31, 31, 'DELIVERED'),
#  (9, 25, 30, 30, 'DELIVERED'),
#  (12, 31, 40, 51, 'DELIVERED'),
#  (13, 32, 40, 44, 'DELIVERED'),
#  (14, 33, 40, 52, 'DELIVERED'),
#  (15, 34, 40, 48, 'DELIVERED'),
#  (16, 35, 40, 46, 'DELIVERED'),
#  (17, 36, 40, 48, 'DELIVERED'),
#  (18, 37, 40, 54, 'DELIVERED'),
#  (19, 38, 40, 43, 'DELIVERED'),
#  (20, 39, 40, 54, 'DELIVERED'),
#  (21, 41, 40, 47, 'DELIVERED'),
#  (22, 42, 40, 40, 'DELIVERED'),
#  (23, 43, 40, 31, 'DELIVERED'),
#  (24, 44, 40, 57, 'DELIVERED'),
#  (25, 47, 40, 49, 'DELIVERED'),
#  (26, 48, 40, 23, 'DELIVERED'),
#  (27, 49, 40, 51, 'DELIVERED'),
#  (28, 50, 40, 58, 'DELIVERED'),
#  (29, 51, 40, 52, 'DELIVERED'),
#  (30, 52, 40, 57, 'DELIVERED'),
#  (31, 53, 40, 22, 'DELIVERED'),
#  (32, 54, 40, 48, 'DELIVERED'),
#  (33, 56, 40, 20, 'DELIVERED'),
#  (34, 57, 40, 59, 'DELIVERED'),
#  (35, 58, 40, 57, 'DELIVERED'),
#  (36, 59, 40, 42, 'DELIVERED'),
#  (37, 60, 40, 43, 'DELIVERED'),
#  (38, 63, 40, 20, 'DELIVERED'),
#  (39, 64, 40, 57, 'DELIVERED'),
#  (40, 65, 40, 33, 'DELIVERED'),
#  (41, 67, 40, 53, 'DELIVERED'),
#  (42, 68, 40, 34, 'DELIVERED'),
#  (43, 69, 40, 29, 'DELIVERED'),
#  (44, 70, 40, 55, 'DELIVERED'),
#  (45, 72, 40, 50, 'DELIVERED'),
#  (46, 74, 40, 39, 'DELIVERED'),
#  (47, 75, 40, 49, 'DELIVERED'),
#  (48, 76, 40, 32, 'DELIVERED'),
#  (49, 77, 40, 43, 'DELIVERED'),
#  (50, 78, 40, 50, 'DELIVERED'),
#  (51, 79, 40, 30, 'DELIVERED'),
#  (52, 80, 40, 47, 'DELIVERED'),
#  (53, 81, 40, 53, 'DELIVERED'),
#  (54, 82, 40, 21, 'DELIVERED'),
#  (55, 83, 40, 52, 'DELIVERED'),
#  (56, 84, 40, 34, 'DELIVERED'),
#  (57, 85, 40, 60, 'DELIVERED'),
#  (58, 86, 40, 57, 'DELIVERED'),
#  (59, 88, 40, 53, 'DELIVERED'),
#  (60, 89, 40, 33, 'DELIVERED'),
#  (61, 90, 40, 27, 'DELIVERED'),
#  (62, 91, 40, 48, 'DELIVERED'),
#  (63, 92, 40, 50, 'DELIVERED'),
#  (64, 93, 40, 33, 'DELIVERED'),
#  (65, 95, 40, 57, 'DELIVERED'),
#  (66, 96, 40, 48, 'DELIVERED'),
#  (67, 100, 40, 42, 'DELIVERED'),
#  (68, 101, 40, 36, 'DELIVERED'),
#  (69, 102, 40, 39, 'DELIVERED'),
#  (70, 103, 40, 57, 'DELIVERED'),
#  (71, 104, 40, 29, 'DELIVERED'),
#  (72, 105, 40, 32, 'DELIVERED'),
#  (73, 106, 40, 40, 'DELIVERED'),
#  (74, 107, 40, 36, 'DELIVERED'),
#  (75, 108, 40, 28, 'DELIVERED'),
#  (76, 109, 40, 59, 'DELIVERED'),
#  (77, 110, 40, 36, 'DELIVERED'),
#  (78, 111, 40, 40, 'DELIVERED'),
#  (79, 112, 40, 25, 'DELIVERED'),
#  (80, 115, 40, 24, 'DELIVERED'),
#  (81, 116, 40, 56, 'DELIVERED'),
#  (82, 117, 40, 43, 'DELIVERED'),
#  (83, 118, 40, 56, 'DELIVERED'),
#  (84, 119, 40, 57, 'DELIVERED'),
#  (85, 120, 40, 38, 'DELIVERED'),
#  (86, 124, 40, 33, 'DELIVERED'),
#  (87, 125, 40, 36, 'DELIVERED'),
#  (88, 127, 40, 30, 'DELIVERED'),
#  (89, 129, 40, 52, 'DELIVERED'),
#  (90, 130, 40, 21, 'DELIVERED'),
#  (91, 132, 40, 45, 'DELIVERED'),
#  (92, 134, 40, 60, 'DELIVERED'),
#  (93, 135, 40, 34, 'DELIVERED'),
#  (94, 136, 40, 48, 'DELIVERED'),
#  (95, 138, 40, 30, 'DELIVERED'),
#  (96, 139, 40, 43, 'DELIVERED'),
#  (97, 140, 40, 30, 'DELIVERED'),
#  (98, 141, 40, 52, 'DELIVERED'),
#  (99, 142, 40, 41, 'DELIVERED'),
#  (100, 143, 40, 56, 'DELIVERED'),
#  (101, 144, 40, 32, 'DELIVERED'),
#  (102, 145, 40, 43, 'DELIVERED'),
#  (103, 147, 40, 49, 'DELIVERED'),
#  (104, 148, 40, 53, 'DELIVERED'),
#  (105, 149, 40, 26, 'DELIVERED'),
#  (106, 150, 40, 28, 'DELIVERED'),
#  (107, 151, 40, 42, 'DELIVERED'),
#  (108, 152, 40, 36, 'DELIVERED'),
#  (109, 153, 40, 39, 'DELIVERED'),
#  (110, 154, 40, 41, 'DELIVERED'),
#  (111, 155, 40, 58, 'DELIVERED'),
#  (112, 156, 40, 32, 'DELIVERED'),
#  (113, 157, 40, 20, 'DELIVERED'),
#  (114, 158, 40, 32, 'DELIVERED'),
#  (115, 159, 40, 53, 'DELIVERED'),
#  (116, 160, 40, 22, 'DELIVERED'),
#  (117, 161, 40, 49, 'DELIVERED'),
#  (118, 162, 40, 30, 'DELIVERED'),
#  (119, 163, 40, 26, 'DELIVERED'),
#  (120, 166, 40, 40, 'DELIVERED'),
#  (121, 167, 40, 21, 'DELIVERED'),
#  (122, 168, 40, 26, 'DELIVERED'),
#  (123, 169, 40, 23, 'DELIVERED'),
#  (124, 170, 40, 59, 'DELIVERED'),
#  (125, 171, 40, 57, 'DELIVERED'),
#  (126, 172, 40, 22, 'DELIVERED'),
#  (127, 173, 40, 57, 'DELIVERED'),
#  (128, 174, 40, 57, 'DELIVERED'),
#  (129, 175, 40, 20, 'DELIVERED'),
#  (130, 176, 40, 54, 'DELIVERED'),
#  (131, 177, 40, 52, 'DELIVERED'),
#  (132, 178, 40, 58, 'DELIVERED'),
#  (133, 179, 40, 48, 'DELIVERED'),
#  (134, 180, 40, 22, 'DELIVERED'),
#  (135, 181, 40, 37, 'DELIVERED'),
#  (136, 182, 40, 38, 'DELIVERED'),
#  (137, 183, 40, 44, 'DELIVERED'),
#  (138, 185, 40, 39, 'DELIVERED'),
#  (139, 186, 40, 20, 'DELIVERED'),
#  (140, 187, 40, 54, 'DELIVERED'),
#  (141, 188, 40, 45, 'DELIVERED'),
#  (142, 189, 40, 51, 'DELIVERED'),
#  (143, 190, 40, 25, 'DELIVERED'),
#  (144, 192, 40, 42, 'DELIVERED'),
#  (145, 193, 40, 49, 'DELIVERED'),
#  (146, 194, 40, 20, 'DELIVERED'),
#  (147, 195, 40, 34, 'DELIVERED'),
#  (148, 196, 40, 34, 'DELIVERED'),
#  (149, 197, 40, 24, 'DELIVERED'),
#  (150, 198, 40, 48, 'DELIVERED'),
#  (151, 199, 40, 54, 'DELIVERED'),
#  (152, 200, 40, 25, 'DELIVERED'),
#  (153, 201, 40, 44, 'DELIVERED'),
#  (154, 202, 40, 20, 'DELIVERED'),
#  (155, 203, 40, 32, 'DELIVERED'),
#  (156, 204, 40, 41, 'DELIVERED'),
#  (157, 205, 40, 30, 'DELIVERED'),
#  (158, 207, 40, 54, 'DELIVERED'),
#  (159, 210, 40, 34, 'DELIVERED'),
#  (160, 211, 40, 22, 'DELIVERED'),
#  (161, 212, 40, 55, 'DELIVERED'),
#  (162, 213, 40, 22, 'DELIVERED'),
#  (163, 215, 40, 56, 'DELIVERED'),
#  (164, 216, 40, 36, 'DELIVERED'),
#  (165, 217, 40, 30, 'DELIVERED'),
#  (166, 218, 40, 45, 'DELIVERED'),
#  (167, 219, 40, 26, 'DELIVERED'),
#  (168, 220, 40, 20, 'DELIVERED'),
#  (169, 221, 40, 39, 'DELIVERED'),
#  (170, 223, 40, 25, 'DELIVERED'),
#  (171, 228, 40, 56, 'DELIVERED'),
#  (172, 229, 40, 40, 'DELIVERED'),
#  (173, 230, 40, 60, 'DELIVERED'),
#  (174, 231, 40, 28, 'DELIVERED'),
#  (175, 232, 40, 30, 'DELIVERED'),
#  (176, 233, 40, 49, 'DELIVERED'),
#  (177, 234, 40, 44, 'DELIVERED'),
#  (178, 235, 40, 23, 'DELIVERED'),
#  (179, 236, 40, 56, 'DELIVERED'),
#  (180, 237, 40, 20, 'DELIVERED'),
#  (181, 238, 40, 25, 'DELIVERED'),
#  (182, 239, 40, 57, 'DELIVERED'),
#  (183, 241, 40, 49, 'DELIVERED'),
#  (184, 242, 40, 42, 'DELIVERED'),
#  (185, 243, 40, 26, 'DELIVERED'),
#  (186, 244, 40, 56, 'DELIVERED'),
#  (187, 246, 40, 26, 'DELIVERED'),
#  (188, 247, 40, 54, 'DELIVERED'),
#  (189, 248, 40, 20, 'DELIVERED'),
#  (190, 249, 40, 40, 'DELIVERED'),
#  (191, 250, 40, 20, 'DELIVERED'),
#  (192, 251, 40, 36, 'DELIVERED'),
#  (193, 252, 40, 27, 'DELIVERED'),
#  (194, 253, 40, 35, 'DELIVERED'),
#  (195, 254, 40, 55, 'DELIVERED'),
#  (196, 255, 40, 24, 'DELIVERED'),
#  (197, 256, 40, 25, 'DELIVERED'),
#  (198, 257, 40, 34, 'DELIVERED'),
#  (199, 258, 40, 38, 'DELIVERED'),
#  (200, 260, 40, 28, 'DELIVERED'),
#  (201, 261, 40, 33, 'DELIVERED'),
#  (202, 264, 40, 39, 'DELIVERED'),
#  (203, 265, 40, 49, 'DELIVERED'),
#  (204, 267, 40, 60, 'DELIVERED'),
#  (205, 269, 40, 37, 'DELIVERED'),
#  (206, 270, 40, 49, 'DELIVERED'),
#  (207, 271, 40, 36, 'DELIVERED'),
#  (208, 272, 40, 48, 'DELIVERED'),
#  (209, 274, 40, 46, 'DELIVERED'),
#  (210, 276, 40, 35, 'DELIVERED'),
#  (211, 277, 40, 46, 'DELIVERED'),
#  (212, 278, 40, 52, 'DELIVERED'),
#  (213, 279, 40, 50, 'DELIVERED'),
#  (214, 280, 40, 36, 'DELIVERED'),
#  (215, 281, 40, 46, 'DELIVERED'),
#  (216, 283, 40, 50, 'DELIVERED'),
#  (217, 285, 40, 52, 'DELIVERED'),
#  (218, 286, 40, 51, 'DELIVERED'),
#  (219, 288, 40, 45, 'DELIVERED'),
#  (220, 289, 40, 25, 'DELIVERED'),
#  (221, 290, 40, 47, 'DELIVERED'),
#  (222, 291, 40, 52, 'DELIVERED'),
#  (223, 292, 40, 24, 'DELIVERED'),
#  (224, 293, 40, 52, 'DELIVERED'),
#  (225, 294, 40, 22, 'DELIVERED'),
#  (226, 295, 40, 30, 'DELIVERED'),
#  (227, 296, 40, 35, 'DELIVERED'),
#  (228, 297, 40, 20, 'DELIVERED'),
#  (229, 298, 40, 48, 'DELIVERED'),
#  (230, 299, 40, 29, 'DELIVERED'),
#  (231, 301, 40, 23, 'DELIVERED'),
#  (232, 302, 40, 37, 'DELIVERED'),
#  (233, 303, 40, 41, 'DELIVERED'),
#  (234, 304, 40, 44, 'DELIVERED'),
#  (235, 306, 40, 59, 'DELIVERED'),
#  (236, 307, 40, 53, 'DELIVERED'),
#  (237, 308, 40, 38, 'DELIVERED'),
#  (238, 309, 40, 51, 'DELIVERED'),
#  (239, 310, 40, 27, 'DELIVERED'),
#  (240, 313, 40, 26, 'DELIVERED'),
#  (241, 314, 40, 57, 'DELIVERED'),
#  (242, 315, 40, 53, 'DELIVERED'),
#  (243, 316, 40, 36, 'DELIVERED'),
#  (244, 317, 40, 52, 'DELIVERED'),
#  (245, 318, 40, 42, 'DELIVERED'),
#  (246, 319, 40, 49, 'DELIVERED'),
#  (247, 320, 40, 51, 'DELIVERED'),
#  (248, 321, 40, 24, 'DELIVERED'),
#  (249, 322, 40, 55, 'DELIVERED'),
#  (250, 323, 40, 35, 'DELIVERED'),
#  (251, 324, 40, 29, 'DELIVERED'),
#  (252, 325, 40, 34, 'DELIVERED'),
#  (253, 326, 40, 47, 'DELIVERED'),
#  (254, 327, 40, 41, 'DELIVERED'),
#  (255, 330, 40, 26, 'DELIVERED'),
#  (256, 333, 40, 58, 'DELIVERED'),
#  (257, 335, 40, 33, 'DELIVERED'),
#  (258, 336, 40, 51, 'DELIVERED'),
#  (259, 337, 40, 27, 'DELIVERED'),
#  (260, 338, 40, 47, 'DELIVERED'),
#  (261, 339, 40, 48, 'DELIVERED'),
#  (262, 341, 40, 36, 'DELIVERED'),
#  (263, 342, 40, 29, 'DELIVERED'),
#  (264, 343, 40, 45, 'DELIVERED'),
#  (265, 344, 40, 41, 'DELIVERED'),
#  (266, 345, 40, 21, 'DELIVERED'),
#  (267, 346, 40, 22, 'DELIVERED'),
#  (268, 347, 40, 49, 'DELIVERED'),
#  (269, 348, 40, 20, 'DELIVERED'),
#  (270, 349, 40, 52, 'DELIVERED'),
#  (271, 350, 40, 44, 'DELIVERED'),
#  (272, 351, 40, 30, 'DELIVERED'),
#  (273, 353, 40, 57, 'DELIVERED'),
#  (274, 354, 40, 36, 'DELIVERED'),
#  (275, 355, 40, 30, 'DELIVERED'),
#  (276, 356, 40, 49, 'DELIVERED'),
#  (277, 357, 40, 51, 'DELIVERED'),
#  (278, 358, 40, 43, 'DELIVERED'),
#  (279, 359, 40, 44, 'DELIVERED'),
#  (280, 360, 40, 34, 'DELIVERED'),
#  (281, 361, 40, 41, 'DELIVERED'),
#  (282, 362, 40, 32, 'DELIVERED'),
#  (283, 363, 40, 53, 'DELIVERED'),
#  (284, 365, 40, 45, 'DELIVERED'),
#  (285, 368, 40, 47, 'DELIVERED'),
#  (286, 369, 40, 50, 'DELIVERED'),
#  (287, 370, 40, 35, 'DELIVERED'),
#  (288, 371, 40, 44, 'DELIVERED'),
#  (289, 372, 40, 23, 'DELIVERED'),
#  (290, 373, 40, 22, 'DELIVERED'),
#  (291, 374, 40, 44, 'DELIVERED'),
#  (292, 375, 40, 33, 'DELIVERED'),
#  (293, 376, 40, 46, 'DELIVERED'),
#  (294, 377, 40, 55, 'DELIVERED'),
#  (295, 379, 40, 35, 'DELIVERED'),
#  (296, 380, 40, 55, 'DELIVERED'),
#  (297, 381, 40, 31, 'DELIVERED'),
#  (298, 382, 40, 57, 'DELIVERED'),
#  (299, 383, 40, 57, 'DELIVERED'),
#  (300, 384, 40, 30, 'DELIVERED'),
#  (301, 385, 40, 22, 'DELIVERED'),
#  (302, 386, 40, 21, 'DELIVERED'),
#  (303, 387, 40, 43, 'DELIVERED'),
#  (304, 390, 40, 36, 'DELIVERED'),
#  (305, 391, 40, 44, 'DELIVERED'),
#  (306, 392, 40, 28, 'DELIVERED'),
#  (307, 393, 40, 41, 'DELIVERED'),
#  (308, 394, 40, 49, 'DELIVERED'),
#  (309, 395, 40, 47, 'DELIVERED'),
#  (310, 396, 40, 50, 'DELIVERED'),
#  (311, 397, 40, 28, 'DELIVERED'),
#  (312, 398, 40, 27, 'DELIVERED'),
#  (313, 399, 40, 54, 'DELIVERED'),
#  (314, 400, 40, 34, 'DELIVERED'),
#  (315, 402, 40, 20, 'DELIVERED'),
#  (316, 403, 40, 48, 'DELIVERED'),
#  (317, 404, 40, 33, 'DELIVERED'),
#  (318, 405, 40, 31, 'DELIVERED'),
#  (319, 406, 40, 55, 'DELIVERED'),
#  (320, 407, 40, 54, 'DELIVERED'),
#  (321, 408, 40, 43, 'DELIVERED'),
#  (322, 409, 40, 45, 'DELIVERED'),
#  (323, 410, 40, 46, 'DELIVERED'),
#  (324, 411, 40, 31, 'DELIVERED'),
#  (325, 412, 40, 60, 'DELIVERED'),
#  (326, 415, 40, 39, 'DELIVERED'),
#  (327, 416, 40, 44, 'DELIVERED'),
#  (328, 417, 40, 37, 'DELIVERED'),
#  (329, 418, 40, 29, 'DELIVERED'),
#  (330, 419, 40, 52, 'DELIVERED'),
#  (331, 420, 40, 24, 'DELIVERED'),
#  (332, 421, 40, 51, 'DELIVERED'),
#  (333, 422, 40, 36, 'DELIVERED'),
#  (334, 424, 40, 46, 'DELIVERED'),
#  (335, 425, 40, 28, 'DELIVERED'),
#  (336, 426, 40, 60, 'DELIVERED'),
#  (337, 427, 40, 55, 'DELIVERED'),
#  (338, 428, 40, 22, 'DELIVERED'),
#  (339, 429, 40, 22, 'DELIVERED'),
#  (340, 430, 40, 44, 'DELIVERED'),
#  (341, 431, 40, 25, 'DELIVERED'),
#  (342, 432, 40, 47, 'DELIVERED'),
#  (343, 433, 40, 39, 'DELIVERED'),
#  (344, 434, 40, 41, 'DELIVERED'),
#  (345, 436, 40, 50, 'DELIVERED'),
#  (346, 437, 40, 29, 'DELIVERED'),
#  (347, 438, 40, 38, 'DELIVERED'),
#  (348, 439, 40, 50, 'DELIVERED'),
#  (349, 440, 40, 54, 'DELIVERED'),
#  (350, 441, 40, 32, 'DELIVERED'),
#  (351, 442, 40, 22, 'DELIVERED'),
#  (352, 443, 40, 37, 'DELIVERED'),
#  (353, 445, 40, 41, 'DELIVERED'),
#  (354, 446, 40, 56, 'DELIVERED'),
#  (355, 447, 40, 27, 'DELIVERED'),
#  (356, 448, 40, 22, 'DELIVERED'),
#  (357, 449, 40, 42, 'DELIVERED'),
#  (358, 450, 40, 30, 'DELIVERED'),
#  (359, 451, 40, 44, 'DELIVERED'),
#  (360, 452, 40, 31, 'DELIVERED'),
#  (361, 453, 40, 34, 'DELIVERED'),
#  (362, 455, 40, 59, 'DELIVERED'),
#  (363, 456, 40, 22, 'DELIVERED'),
#  (364, 458, 40, 42, 'DELIVERED'),
#  (365, 459, 40, 30, 'DELIVERED'),
#  (366, 460, 40, 42, 'DELIVERED'),
#  (367, 461, 40, 50, 'DELIVERED'),
#  (368, 463, 40, 20, 'DELIVERED'),
#  (369, 465, 40, 55, 'DELIVERED'),
#  (370, 467, 40, 60, 'DELIVERED'),
#  (371, 468, 40, 39, 'DELIVERED'),
#  (372, 469, 40, 32, 'DELIVERED'),
#  (373, 470, 40, 51, 'DELIVERED'),
#  (374, 471, 40, 50, 'DELIVERED'),
#  (375, 472, 40, 45, 'DELIVERED'),
#  (376, 474, 40, 31, 'DELIVERED'),
#  (377, 475, 40, 55, 'DELIVERED'),
#  (378, 477, 40, 31, 'DELIVERED'),
#  (379, 478, 40, 29, 'DELIVERED'),
#  (380, 479, 40, 47, 'DELIVERED'),
#  (381, 480, 40, 35, 'DELIVERED'),
#  (382, 481, 40, 41, 'DELIVERED'),
#  (383, 482, 40, 23, 'DELIVERED'),
#  (384, 483, 40, 41, 'DELIVERED'),
#  (385, 484, 40, 35, 'DELIVERED'),
#  (386, 485, 40, 35, 'DELIVERED'),
#  (387, 486, 40, 22, 'DELIVERED'),
#  (388, 488, 40, 23, 'DELIVERED'),
#  (389, 489, 40, 26, 'DELIVERED'),
#  (390, 490, 40, 48, 'DELIVERED'),
#  (391, 492, 40, 29, 'DELIVERED'),
#  (392, 493, 40, 29, 'DELIVERED'),
#  (393, 494, 40, 39, 'DELIVERED'),
#  (394, 495, 40, 34, 'DELIVERED'),
#  (395, 496, 40, 37, 'DELIVERED'),
#  (396, 497, 40, 45, 'DELIVERED'),
#  (397, 498, 40, 29, 'DELIVERED'),
#  (398, 499, 40, 36, 'DELIVERED'),
#  (399, 500, 40, 55, 'DELIVERED'),
#  (400, 501, 40, 60, 'DELIVERED'),
#  (401, 502, 40, 45, 'DELIVERED'),
#  (402, 503, 40, 32, 'DELIVERED'),
#  (403, 504, 40, 32, 'DELIVERED'),
#  (404, 505, 40, 42, 'DELIVERED'),
#  (405, 506, 40, 51, 'DELIVERED'),
#  (406, 507, 40, 44, 'DELIVERED'),
#  (407, 509, 40, 56, 'DELIVERED'),
#  (408, 510, 40, 41, 'DELIVERED'),
#  (409, 511, 40, 26, 'DELIVERED'),
#  (410, 512, 40, 32, 'DELIVERED'),
#  (411, 513, 40, 50, 'DELIVERED'),
#  (412, 514, 40, 27, 'DELIVERED'),
#  (413, 515, 40, 35, 'DELIVERED'),
#  (414, 516, 40, 47, 'DELIVERED'),
#  (415, 517, 40, 20, 'DELIVERED'),
#  (416, 518, 40, 28, 'DELIVERED'),
#  (417, 521, 40, 29, 'DELIVERED'),
#  (418, 522, 40, 48, 'DELIVERED'),
#  (419, 523, 40, 33, 'DELIVERED'),
#  (420, 524, 40, 39, 'DELIVERED'),
#  (421, 525, 40, 49, 'DELIVERED'),
#  (422, 527, 40, 54, 'DELIVERED'),
#  (423, 528, 40, 58, 'DELIVERED'),
#  (424, 529, 40, 52, 'DELIVERED'),
#  (425, 530, 40, 23, 'DELIVERED'),
#  (426, 532, 40, 27, 'DELIVERED'),
#  (427, 533, 40, 32, 'DELIVERED'),
#  (428, 534, 40, 59, 'DELIVERED'),
#  (429, 535, 40, 56, 'DELIVERED'),
#  (430, 536, 40, 39, 'DELIVERED'),
#  (431, 537, 40, 36, 'DELIVERED'),
#  (432, 539, 40, 58, 'DELIVERED'),
#  (433, 544, 40, 53, 'DELIVERED'),
#  (434, 546, 40, 54, 'DELIVERED'),
#  (435, 547, 40, 47, 'DELIVERED'),
#  (436, 548, 40, 48, 'DELIVERED'),
#  (437, 549, 40, 49, 'DELIVERED'),
#  (438, 550, 40, 38, 'DELIVERED'),
#  (439, 551, 40, 45, 'DELIVERED'),
#  (440, 552, 40, 48, 'DELIVERED'),
#  (441, 553, 40, 31, 'DELIVERED'),
#  (442, 556, 40, 42, 'DELIVERED'),
#  (443, 557, 40, 38, 'DELIVERED'),
#  (444, 558, 40, 38, 'DELIVERED'),
#  (445, 559, 40, 46, 'DELIVERED'),
#  (446, 560, 40, 22, 'DELIVERED'),
#  (447, 561, 40, 42, 'DELIVERED'),
#  (448, 562, 40, 36, 'DELIVERED'),
#  (449, 563, 40, 59, 'DELIVERED'),
#  (450, 564, 40, 49, 'DELIVERED'),
#  (451, 565, 40, 31, 'DELIVERED'),
#  (452, 566, 40, 46, 'DELIVERED'),
#  (453, 567, 40, 37, 'DELIVERED'),
#  (454, 569, 40, 41, 'DELIVERED'),
#  (455, 571, 40, 27, 'DELIVERED'),
#  (456, 572, 40, 25, 'DELIVERED'),
#  (457, 573, 40, 49, 'DELIVERED'),
#  (458, 574, 40, 31, 'DELIVERED'),
#  (459, 576, 40, 41, 'DELIVERED'),
#  (460, 577, 40, 35, 'DELIVERED'),
#  (461, 578, 40, 44, 'DELIVERED'),
#  (462, 579, 40, 51, 'DELIVERED'),
#  (463, 580, 40, 56, 'DELIVERED'),
#  (464, 581, 40, 40, 'DELIVERED'),
#  (465, 582, 40, 33, 'DELIVERED'),
#  (466, 583, 40, 40, 'DELIVERED'),
#  (467, 585, 40, 59, 'DELIVERED'),
#  (468, 586, 40, 53, 'DELIVERED'),
#  (469, 587, 40, 24, 'DELIVERED'),
#  (470, 588, 40, 47, 'DELIVERED'),
#  (471, 589, 40, 53, 'DELIVERED'),
#  (472, 590, 40, 50, 'DELIVERED'),
#  (473, 591, 40, 24, 'DELIVERED'),
#  (474, 592, 40, 50, 'DELIVERED'),
#  (475, 593, 40, 28, 'DELIVERED'),
#  (476, 594, 40, 46, 'DELIVERED'),
#  (477, 595, 40, 50, 'DELIVERED'),
#  (478, 598, 40, 52, 'DELIVERED'),
#  (479, 601, 40, 33, 'DELIVERED'),
#  (480, 602, 40, 36, 'DELIVERED'),
#  (481, 603, 40, 38, 'DELIVERED'),
#  (482, 604, 40, 48, 'DELIVERED'),
#  (483, 605, 40, 54, 'DELIVERED'),
#  (484, 606, 40, 48, 'DELIVERED'),
#  (485, 607, 40, 31, 'DELIVERED'),
#  (486, 608, 40, 38, 'DELIVERED'),
#  (487, 609, 40, 27, 'DELIVERED'),
#  (488, 610, 40, 22, 'DELIVERED'),
#  (489, 611, 40, 52, 'DELIVERED'),
#  (490, 612, 40, 21, 'DELIVERED'),
#  (491, 613, 40, 25, 'DELIVERED'),
#  (492, 614, 40, 29, 'DELIVERED'),
#  (493, 615, 40, 35, 'DELIVERED'),
#  (494, 616, 40, 48, 'DELIVERED'),
#  (495, 617, 40, 28, 'DELIVERED'),
#  (496, 618, 40, 20, 'DELIVERED'),
#  (497, 621, 40, 22, 'DELIVERED'),
#  (498, 622, 40, 26, 'DELIVERED'),
#  (499, 623, 40, 26, 'DELIVERED'),
#  (500, 625, 40, 22, 'DELIVERED'),
#  (501, 626, 40, 28, 'DELIVERED'),
#  (502, 628, 40, 46, 'DELIVERED'),
#  (503, 629, 40, 41, 'DELIVERED'),
#  (504, 631, 40, 46, 'DELIVERED'),
#  (505, 633, 40, 52, 'DELIVERED'),
#  (506, 636, 40, 47, 'DELIVERED'),
#  (507, 637, 40, 58, 'DELIVERED'),
#  (508, 640, 40, 51, 'DELIVERED'),
#  (509, 641, 40, 48, 'DELIVERED'),
#  (510, 642, 40, 39, 'DELIVERED'),
#  (511, 643, 40, 50, 'DELIVERED'),
#  (512, 644, 40, 34, 'DELIVERED'),
#  (513, 647, 40, 60, 'DELIVERED'),
#  (514, 648, 40, 59, 'DELIVERED'),
#  (515, 649, 40, 54, 'DELIVERED'),
#  (516, 650, 40, 32, 'DELIVERED'),
#  (517, 651, 40, 22, 'DELIVERED'),
#  (518, 652, 40, 59, 'DELIVERED'),
#  (519, 653, 40, 22, 'DELIVERED'),
#  (520, 654, 40, 22, 'DELIVERED'),
#  (521, 655, 40, 27, 'DELIVERED'),
#  (522, 657, 40, 27, 'DELIVERED'),
#  (523, 659, 40, 28, 'DELIVERED'),
#  (524, 661, 40, 52, 'DELIVERED'),
#  (525, 662, 40, 41, 'DELIVERED'),
#  (526, 663, 40, 51, 'DELIVERED'),
#  (527, 664, 40, 44, 'DELIVERED'),
#  (528, 665, 40, 32, 'DELIVERED'),
#  (529, 666, 40, 56, 'DELIVERED'),
#  (530, 667, 40, 59, 'DELIVERED'),
#  (531, 668, 40, 33, 'DELIVERED'),
#  (532, 669, 40, 25, 'DELIVERED'),
#  (533, 670, 40, 26, 'DELIVERED'),
#  (534, 671, 40, 50, 'DELIVERED'),
#  (535, 672, 40, 39, 'DELIVERED'),
#  (536, 674, 40, 55, 'DELIVERED'),
#  (537, 675, 40, 23, 'DELIVERED'),
#  (538, 676, 40, 40, 'DELIVERED'),
#  (539, 679, 40, 22, 'DELIVERED'),
#  (540, 680, 40, 25, 'DELIVERED'),
#  (541, 681, 40, 41, 'DELIVERED'),
#  (542, 682, 40, 24, 'DELIVERED'),
#  (543, 683, 40, 52, 'DELIVERED'),
#  (544, 684, 40, 52, 'DELIVERED'),
#  (545, 685, 40, 54, 'DELIVERED'),
#  (546, 686, 40, 58, 'DELIVERED'),
#  (547, 688, 40, 26, 'DELIVERED'),
#  (548, 689, 40, 49, 'DELIVERED'),
#  (549, 690, 40, 25, 'DELIVERED'),
#  (550, 691, 40, 50, 'DELIVERED'),
#  (551, 692, 40, 53, 'DELIVERED'),
#  (552, 694, 40, 29, 'DELIVERED'),
#  (553, 695, 40, 46, 'DELIVERED'),
#  (554, 696, 40, 43, 'DELIVERED'),
#  (555, 697, 40, 59, 'DELIVERED'),
#  (556, 698, 40, 60, 'DELIVERED'),
#  (557, 701, 40, 54, 'DELIVERED'),
#  (558, 702, 40, 32, 'DELIVERED'),
#  (559, 703, 40, 54, 'DELIVERED'),
#  (560, 704, 40, 50, 'DELIVERED'),
#  (561, 705, 40, 37, 'DELIVERED'),
#  (562, 706, 40, 59, 'DELIVERED'),
#  (563, 707, 40, 25, 'DELIVERED'),
#  (564, 708, 40, 60, 'DELIVERED'),
#  (565, 709, 40, 30, 'DELIVERED'),
#  (566, 710, 40, 56, 'DELIVERED'),
#  (567, 711, 40, 21, 'DELIVERED'),
#  (568, 712, 40, 40, 'DELIVERED'),
#  (569, 713, 40, 38, 'DELIVERED'),
#  (570, 714, 40, 25, 'DELIVERED'),
#  (571, 715, 40, 55, 'DELIVERED'),
#  (572, 716, 40, 36, 'DELIVERED'),
#  (573, 717, 40, 29, 'DELIVERED'),
#  (574, 718, 40, 50, 'DELIVERED'),
#  (575, 720, 40, 37, 'DELIVERED'),
#  (576, 722, 40, 27, 'DELIVERED'),
#  (577, 723, 40, 39, 'DELIVERED'),
#  (578, 726, 40, 57, 'DELIVERED'),
#  (579, 727, 40, 48, 'DELIVERED'),
#  (580, 728, 40, 33, 'DELIVERED'),
#  (581, 729, 40, 47, 'DELIVERED'),
#  (582, 731, 40, 45, 'DELIVERED'),
#  (583, 732, 40, 49, 'DELIVERED'),
#  (584, 733, 40, 40, 'DELIVERED'),
#  (585, 736, 40, 39, 'DELIVERED'),
#  (586, 737, 40, 20, 'DELIVERED'),
#  (587, 738, 40, 21, 'DELIVERED'),
#  (588, 739, 40, 37, 'DELIVERED'),
#  (589, 741, 40, 60, 'DELIVERED'),
#  (590, 742, 40, 54, 'DELIVERED'),
#  (591, 743, 40, 58, 'DELIVERED'),
#  (592, 744, 40, 57, 'DELIVERED'),
#  (593, 745, 40, 49, 'DELIVERED'),
#  (594, 747, 40, 34, 'DELIVERED'),
#  (595, 748, 40, 44, 'DELIVERED'),
#  (596, 749, 40, 27, 'DELIVERED'),
#  (597, 750, 40, 57, 'DELIVERED'),
#  (598, 752, 40, 32, 'DELIVERED'),
#  (599, 753, 40, 26, 'DELIVERED'),
#  (600, 756, 40, 43, 'DELIVERED'),
#  (601, 757, 40, 53, 'DELIVERED'),
#  (602, 759, 40, 27, 'DELIVERED'),
#  (603, 760, 40, 22, 'DELIVERED'),
#  (604, 761, 40, 31, 'DELIVERED'),
#  (605, 762, 40, 44, 'DELIVERED'),
#  (606, 763, 40, 25, 'DELIVERED'),
#  (607, 764, 40, 55, 'DELIVERED'),
#  (608, 765, 40, 36, 'DELIVERED'),
#  (609, 766, 40, 22, 'DELIVERED'),
#  (610, 769, 40, 50, 'DELIVERED'),
#  (611, 770, 40, 50, 'DELIVERED'),
#  (612, 771, 40, 37, 'DELIVERED'),
#  (613, 774, 40, 31, 'DELIVERED'),
#  (614, 775, 40, 34, 'DELIVERED'),
#  (615, 776, 40, 24, 'DELIVERED'),
#  (616, 777, 40, 27, 'DELIVERED'),
#  (617, 779, 40, 52, 'DELIVERED'),
#  (618, 781, 40, 39, 'DELIVERED'),
#  (619, 782, 40, 53, 'DELIVERED'),
#  (620, 783, 40, 36, 'DELIVERED'),
#  (621, 786, 40, 40, 'DELIVERED'),
#  (622, 788, 40, 30, 'DELIVERED'),
#  (623, 789, 40, 28, 'DELIVERED'),
#  (624, 790, 40, 38, 'DELIVERED'),
#  (625, 791, 40, 22, 'DELIVERED'),
#  (626, 793, 40, 50, 'DELIVERED'),
#  (627, 794, 40, 24, 'DELIVERED'),
#  (628, 795, 40, 60, 'DELIVERED'),
#  (629, 796, 40, 36, 'DELIVERED'),
#  (630, 798, 40, 36, 'DELIVERED'),
#  (631, 799, 40, 27, 'DELIVERED'),
#  (632, 800, 40, 31, 'DELIVERED'),
#  (633, 801, 40, 21, 'DELIVERED'),
#  (634, 802, 40, 55, 'DELIVERED'),
#  (635, 803, 40, 49, 'DELIVERED'),
#  (636, 804, 40, 59, 'DELIVERED'),
#  (637, 805, 40, 34, 'DELIVERED'),
#  (638, 806, 40, 60, 'DELIVERED'),
#  (639, 807, 40, 28, 'DELIVERED'),
#  (640, 808, 40, 59, 'DELIVERED'),
#  (641, 809, 40, 31, 'DELIVERED'),
#  (642, 810, 40, 27, 'DELIVERED'),
#  (643, 811, 40, 32, 'DELIVERED'),
#  (644, 812, 40, 37, 'DELIVERED'),
#  (645, 813, 40, 39, 'DELIVERED'),
#  (646, 814, 40, 33, 'DELIVERED'),
#  (647, 815, 40, 31, 'DELIVERED'),
#  (648, 816, 40, 57, 'DELIVERED'),
#  (649, 817, 40, 48, 'DELIVERED'),
#  (650, 818, 40, 42, 'DELIVERED'),
#  (651, 819, 40, 49, 'DELIVERED'),
#  (652, 820, 40, 24, 'DELIVERED'),
#  (653, 821, 40, 58, 'DELIVERED'),
#  (654, 822, 40, 27, 'DELIVERED'),
#  (655, 823, 40, 44, 'DELIVERED'),
#  (656, 824, 40, 44, 'DELIVERED'),
#  (657, 825, 40, 47, 'DELIVERED'),
#  (658, 826, 40, 30, 'DELIVERED'),
#  (659, 827, 40, 25, 'DELIVERED'),
#  (660, 829, 40, 44, 'DELIVERED'),
#  (661, 830, 40, 22, 'DELIVERED'),
#  (662, 831, 40, 45, 'DELIVERED'),
#  (663, 832, 40, 45, 'DELIVERED'),
#  (664, 833, 40, 28, 'DELIVERED'),
#  (665, 834, 40, 20, 'DELIVERED'),
#  (666, 835, 40, 31, 'DELIVERED'),
#  (667, 836, 40, 55, 'DELIVERED'),
#  (668, 837, 40, 51, 'DELIVERED'),
#  (669, 838, 40, 46, 'DELIVERED'),
#  (670, 839, 40, 22, 'DELIVERED'),
#  (671, 840, 40, 35, 'DELIVERED'),
#  (672, 841, 40, 33, 'DELIVERED'),
#  (673, 842, 40, 60, 'DELIVERED'),
#  (674, 843, 40, 34, 'DELIVERED'),
#  (675, 844, 40, 45, 'DELIVERED'),
#  (676, 845, 40, 20, 'DELIVERED'),
#  (677, 846, 40, 46, 'DELIVERED'),
#  (678, 847, 40, 33, 'DELIVERED'),
#  (679, 848, 40, 60, 'DELIVERED'),
#  (680, 849, 40, 42, 'DELIVERED'),
#  (681, 850, 40, 58, 'DELIVERED'),
#  (682, 851, 40, 32, 'DELIVERED'),
#  (683, 853, 40, 39, 'DELIVERED'),
#  (684, 854, 40, 59, 'DELIVERED'),
#  (685, 855, 40, 29, 'DELIVERED'),
#  (686, 856, 40, 36, 'DELIVERED'),
#  (687, 857, 40, 37, 'DELIVERED'),
#  (688, 859, 40, 52, 'DELIVERED'),
#  (689, 861, 40, 23, 'DELIVERED'),
#  (690, 862, 40, 28, 'DELIVERED'),
#  (691, 863, 40, 32, 'DELIVERED'),
#  (692, 865, 40, 23, 'DELIVERED'),
#  (693, 866, 40, 56, 'DELIVERED'),
#  (694, 867, 40, 45, 'DELIVERED'),
#  (695, 868, 40, 21, 'DELIVERED'),
#  (696, 869, 40, 47, 'DELIVERED'),
#  (697, 871, 40, 22, 'DELIVERED'),
#  (698, 872, 40, 25, 'DELIVERED'),
#  (699, 873, 40, 49, 'DELIVERED'),
#  (700, 874, 40, 35, 'DELIVERED'),
#  (701, 877, 40, 24, 'DELIVERED'),
#  (702, 878, 40, 31, 'DELIVERED'),
#  (703, 879, 40, 29, 'DELIVERED'),
#  (704, 880, 40, 56, 'DELIVERED'),
#  (705, 881, 40, 51, 'DELIVERED'),
#  (706, 882, 40, 59, 'DELIVERED'),
#  (707, 883, 40, 47, 'DELIVERED'),
#  (708, 884, 40, 47, 'DELIVERED'),
#  (709, 885, 40, 60, 'DELIVERED'),
#  (710, 887, 40, 57, 'DELIVERED'),
#  (711, 888, 40, 59, 'DELIVERED'),
#  (712, 889, 40, 28, 'DELIVERED'),
#  (713, 890, 40, 30, 'DELIVERED'),
#  (714, 891, 40, 25, 'DELIVERED'),
#  (715, 892, 40, 46, 'DELIVERED'),
#  (716, 893, 40, 52, 'DELIVERED'),
#  (717, 894, 40, 55, 'DELIVERED'),
#  (718, 896, 40, 39, 'DELIVERED'),
#  (719, 897, 40, 37, 'DELIVERED'),
#  (720, 898, 40, 53, 'DELIVERED'),
#  (721, 900, 40, 53, 'DELIVERED'),
#  (722, 901, 40, 26, 'DELIVERED'),
#  (723, 902, 40, 41, 'DELIVERED'),
#  (724, 903, 40, 37, 'DELIVERED'),
#  (725, 904, 40, 55, 'DELIVERED'),
#  (726, 905, 40, 43, 'DELIVERED'),
#  (727, 907, 40, 41, 'DELIVERED'),
#  (728, 908, 40, 32, 'DELIVERED'),
#  (729, 909, 40, 59, 'DELIVERED'),
#  (730, 910, 40, 58, 'DELIVERED'),
#  (731, 911, 40, 46, 'DELIVERED'),
#  (732, 912, 40, 51, 'DELIVERED'),
#  (733, 913, 40, 50, 'DELIVERED'),
#  (734, 914, 40, 47, 'DELIVERED'),
#  (735, 916, 40, 36, 'DELIVERED'),
#  (736, 917, 40, 37, 'DELIVERED'),
#  (737, 918, 40, 24, 'DELIVERED'),
#  (738, 919, 40, 52, 'DELIVERED'),
#  (739, 921, 40, 24, 'DELIVERED'),
#  (740, 922, 40, 45, 'DELIVERED'),
#  (741, 923, 40, 39, 'DELIVERED'),
#  (742, 924, 40, 39, 'DELIVERED'),
#  (743, 925, 40, 57, 'DELIVERED'),
#  (744, 926, 40, 27, 'DELIVERED'),
#  (745, 927, 40, 59, 'DELIVERED'),
#  (746, 928, 40, 58, 'DELIVERED'),
#  (747, 929, 40, 27, 'DELIVERED'),
#  (748, 930, 40, 51, 'DELIVERED'),
#  (749, 931, 40, 38, 'DELIVERED'),
#  (750, 932, 40, 39, 'DELIVERED'),
#  (751, 933, 40, 32, 'DELIVERED'),
#  (752, 934, 40, 59, 'DELIVERED'),
#  (753, 935, 40, 48, 'DELIVERED'),
#  (754, 937, 40, 59, 'DELIVERED'),
#  (755, 938, 40, 48, 'DELIVERED'),
#  (756, 940, 40, 21, 'DELIVERED'),
#  (757, 941, 40, 48, 'DELIVERED'),
#  (758, 942, 40, 28, 'DELIVERED'),
#  (759, 944, 40, 59, 'DELIVERED'),
#  (760, 945, 40, 36, 'DELIVERED'),
#  (761, 946, 40, 25, 'DELIVERED'),
#  (762, 949, 40, 57, 'DELIVERED'),
#  (763, 950, 40, 44, 'DELIVERED'),
#  (764, 952, 40, 39, 'DELIVERED'),
#  (765, 953, 40, 35, 'DELIVERED'),
#  (766, 954, 40, 34, 'DELIVERED'),
#  (767, 955, 40, 25, 'DELIVERED'),
#  (768, 957, 40, 43, 'DELIVERED'),
#  (769, 959, 40, 47, 'DELIVERED'),
#  (770, 961, 40, 36, 'DELIVERED'),
#  (771, 962, 40, 42, 'DELIVERED'),
#  (772, 963, 40, 60, 'DELIVERED'),
#  (773, 964, 40, 27, 'DELIVERED'),
#  (774, 965, 40, 29, 'DELIVERED'),
#  (775, 966, 40, 41, 'DELIVERED'),
#  (776, 967, 40, 36, 'DELIVERED'),
#  (777, 968, 40, 23, 'DELIVERED'),
#  (778, 969, 40, 22, 'DELIVERED'),
#  (779, 970, 40, 26, 'DELIVERED'),
#  (780, 971, 40, 27, 'DELIVERED'),
#  (781, 972, 40, 42, 'DELIVERED'),
#  (782, 973, 40, 37, 'DELIVERED'),
#  (783, 974, 40, 21, 'DELIVERED'),
#  (784, 975, 40, 55, 'DELIVERED'),
#  (785, 976, 40, 36, 'DELIVERED'),
#  (786, 977, 40, 20, 'DELIVERED'),
#  (787, 978, 40, 29, 'DELIVERED'),
#  (788, 979, 40, 51, 'DELIVERED'),
#  (789, 980, 40, 34, 'DELIVERED'),
#  (790, 981, 40, 47, 'DELIVERED'),
#  (791, 982, 40, 55, 'DELIVERED'),
#  (792, 983, 40, 57, 'DELIVERED'),
#  (793, 984, 40, 43, 'DELIVERED'),
#  (794, 986, 40, 45, 'DELIVERED'),
#  (795, 987, 40, 60, 'DELIVERED'),
#  (796, 988, 40, 43, 'DELIVERED'),
#  (797, 989, 40, 51, 'DELIVERED'),
#  (798, 991, 40, 49, 'DELIVERED'),
#  (799, 994, 40, 32, 'DELIVERED'),
#  (800, 995, 40, 22, 'DELIVERED'),
#  (801, 997, 40, 52, 'DELIVERED'),
#  (802, 998, 40, 23, 'DELIVERED'),
#  (803, 999, 40, 42, 'DELIVERED'),
#  (804, 1000, 40, 38, 'DELIVERED'),
#  (805, 1001, 40, 48, 'DELIVERED'),
#  (806, 1002, 40, 21, 'DELIVERED'),
#  (807, 1003, 40, 39, 'DELIVERED'),
#  (808, 1004, 40, 40, 'DELIVERED'),
#  (809, 1006, 40, 47, 'DELIVERED'),
#  (810, 1007, 40, 44, 'DELIVERED'),
#  (811, 1009, 40, 46, 'DELIVERED'),
#  (812, 1010, 40, 55, 'DELIVERED'),
#  (813, 1011, 40, 32, 'DELIVERED'),
#  (814, 1012, 40, 34, 'DELIVERED'),
#  (815, 1013, 40, 26, 'DELIVERED'),
#  (816, 1014, 40, 52, 'DELIVERED'),
#  (817, 1016, 40, 39, 'DELIVERED'),
#  (818, 1017, 40, 50, 'DELIVERED'),
#  (819, 1019, 40, 53, 'DELIVERED'),
#  (820, 1021, 40, 58, 'DELIVERED'),
#  (821, 1022, 40, 20, 'DELIVERED'),
#  (822, 1023, 40, 56, 'DELIVERED'),
#  (823, 1024, 40, 44, 'DELIVERED'),
#  (824, 1025, 40, 21, 'DELIVERED'),
#  (825, 1026, 40, 44, 'DELIVERED'),
#  (826, 1027, 40, 46, 'DELIVERED'),
#  (827, 1028, 40, 59, 'DELIVERED'),
#  (828, 1031, 40, 34, 'DELIVERED'),
#  (829, 1032, 40, 37, 'DELIVERED'),
#  (830, 1034, 40, 28, 'DELIVERED'),
#  (831, 1035, 40, 41, 'DELIVERED'),
#  (832, 1036, 40, 24, 'DELIVERED'),
#  (833, 1037, 40, 55, 'DELIVERED'),
#  (834, 1038, 40, 49, 'DELIVERED'),
#  (835, 1039, 40, 55, 'DELIVERED'),
#  (836, 1041, 40, 47, 'DELIVERED'),
#  (837, 1042, 40, 32, 'DELIVERED'),
#  (838, 1043, 40, 41, 'DELIVERED'),
#  (839, 1044, 40, 23, 'DELIVERED'),
#  (840, 1046, 40, 23, 'DELIVERED'),
#  (841, 1047, 40, 38, 'DELIVERED'),
#  (842, 1049, 40, 60, 'DELIVERED'),
#  (843, 1050, 40, 35, 'DELIVERED'),
#  (844, 1051, 40, 30, 'DELIVERED'),
#  (845, 1052, 40, 28, 'DELIVERED'),
#  (846, 1053, 40, 46, 'DELIVERED'),
#  (847, 1055, 40, 41, 'DELIVERED'),
#  (848, 1056, 40, 45, 'DELIVERED'),
#  (849, 1057, 40, 25, 'DELIVERED'),
#  (850, 1058, 40, 25, 'DELIVERED'),
#  (851, 1059, 40, 60, 'DELIVERED'),
#  (852, 1060, 40, 28, 'DELIVERED'),
#  (853, 1061, 40, 33, 'DELIVERED'),
#  (854, 1063, 40, 55, 'DELIVERED'),
#  (855, 1064, 40, 40, 'DELIVERED'),
#  (856, 1066, 40, 32, 'DELIVERED'),
#  (857, 1068, 40, 56, 'DELIVERED'),
#  (858, 1069, 40, 20, 'DELIVERED'),
#  (859, 1070, 40, 48, 'DELIVERED'),
#  (860, 1071, 40, 24, 'DELIVERED'),
#  (861, 1072, 40, 51, 'DELIVERED'),
#  (862, 1073, 40, 60, 'DELIVERED'),
#  (863, 1074, 40, 31, 'DELIVERED'),
#  (864, 1076, 40, 53, 'DELIVERED'),
#  (865, 1077, 40, 50, 'DELIVERED'),
#  (866, 1078, 40, 45, 'DELIVERED'),
#  (867, 1079, 40, 42, 'DELIVERED'),
#  (868, 1080, 40, 35, 'DELIVERED'),
#  (869, 1081, 40, 40, 'DELIVERED'),
#  (870, 1084, 40, 48, 'DELIVERED'),
#  (871, 1085, 40, 41, 'DELIVERED'),
#  (872, 1086, 40, 52, 'DELIVERED'),
#  (873, 1087, 40, 25, 'DELIVERED'),
#  (874, 1088, 40, 44, 'DELIVERED'),
#  (875, 1089, 40, 22, 'DELIVERED'),
#  (876, 1091, 40, 36, 'DELIVERED'),
#  (877, 1092, 40, 44, 'DELIVERED'),
#  (878, 1093, 40, 30, 'DELIVERED'),
#  (879, 1094, 40, 36, 'DELIVERED'),
#  (880, 1096, 40, 47, 'DELIVERED'),
#  (881, 1097, 40, 32, 'DELIVERED'),
#  (882, 1099, 40, 49, 'DELIVERED'),
#  (883, 1100, 40, 30, 'DELIVERED'),
#  (884, 1101, 40, 53, 'DELIVERED'),
#  (885, 1103, 40, 33, 'DELIVERED'),
#  (886, 1104, 40, 45, 'DELIVERED'),
#  (887, 1106, 40, 48, 'DELIVERED'),
#  (888, 1107, 40, 31, 'DELIVERED'),
#  (889, 1108, 40, 24, 'DELIVERED'),
#  (890, 1109, 40, 32, 'DELIVERED'),
#  (891, 1110, 40, 44, 'DELIVERED'),
#  (892, 1111, 40, 50, 'DELIVERED'),
#  (893, 1113, 40, 27, 'DELIVERED'),
#  (894, 1115, 40, 22, 'DELIVERED'),
#  (895, 1117, 40, 41, 'DELIVERED'),
#  (896, 1119, 40, 30, 'DELIVERED'),
#  (897, 1120, 40, 21, 'DELIVERED'),
#  (898, 1121, 40, 26, 'DELIVERED'),
#  (899, 1122, 40, 48, 'DELIVERED'),
#  (900, 1123, 40, 34, 'DELIVERED'),
#  (901, 1124, 40, 43, 'DELIVERED'),
#  (902, 1125, 40, 41, 'DELIVERED'),
#  (903, 1128, 40, 43, 'DELIVERED'),
#  (904, 1129, 40, 50, 'DELIVERED'),
#  (905, 1131, 40, 45, 'DELIVERED'),
#  (906, 1132, 40, 28, 'DELIVERED'),
#  (907, 1135, 40, 42, 'DELIVERED'),
#  (908, 1136, 40, 37, 'DELIVERED'),
#  (909, 1138, 40, 33, 'DELIVERED'),
#  (910, 1139, 40, 20, 'DELIVERED'),
#  (911, 1140, 40, 28, 'DELIVERED'),
#  (912, 1141, 40, 50, 'DELIVERED'),
#  (913, 1142, 40, 56, 'DELIVERED'),
#  (914, 1143, 40, 54, 'DELIVERED'),
#  (915, 1144, 40, 58, 'DELIVERED'),
#  (916, 1148, 40, 54, 'DELIVERED'),
#  (917, 1149, 40, 23, 'DELIVERED'),
#  (918, 1150, 40, 23, 'DELIVERED'),
#  (919, 1151, 40, 56, 'DELIVERED'),
#  (920, 1152, 40, 52, 'DELIVERED'),
#  (921, 1153, 40, 58, 'DELIVERED'),
#  (922, 1154, 40, 60, 'DELIVERED'),
#  (923, 1155, 40, 30, 'DELIVERED'),
#  (924, 1156, 40, 33, 'DELIVERED'),
#  (925, 1158, 40, 33, 'DELIVERED'),
#  (926, 1159, 40, 38, 'DELIVERED'),
#  (927, 1160, 40, 41, 'DELIVERED'),
#  (928, 1161, 40, 39, 'DELIVERED'),
#  (929, 1162, 40, 36, 'DELIVERED'),
#  (930, 1163, 40, 29, 'DELIVERED'),
#  (931, 1165, 40, 33, 'DELIVERED'),
#  (932, 1166, 40, 24, 'DELIVERED'),
#  (933, 1169, 40, 32, 'DELIVERED'),
#  (934, 1171, 40, 31, 'DELIVERED'),
#  (935, 1172, 40, 44, 'DELIVERED'),
#  (936, 1173, 40, 24, 'DELIVERED'),
#  (937, 1174, 40, 44, 'DELIVERED'),
#  (938, 1175, 40, 39, 'DELIVERED'),
#  (939, 1176, 40, 36, 'DELIVERED'),
#  (940, 1177, 40, 36, 'DELIVERED'),
#  (941, 1178, 40, 45, 'DELIVERED'),
#  (942, 1179, 40, 59, 'DELIVERED'),
#  (943, 1180, 40, 47, 'DELIVERED'),
#  (944, 1181, 40, 29, 'DELIVERED'),
#  (945, 1182, 40, 44, 'DELIVERED'),
#  (946, 1183, 40, 59, 'DELIVERED'),
#  (947, 1184, 40, 55, 'DELIVERED'),
#  (948, 1185, 40, 57, 'DELIVERED'),
#  (949, 1186, 40, 49, 'DELIVERED'),
#  (950, 1187, 40, 31, 'DELIVERED'),
#  (951, 1188, 40, 27, 'DELIVERED'),
#  (952, 1189, 40, 37, 'DELIVERED'),
#  (953, 1191, 40, 42, 'DELIVERED'),
#  (954, 1192, 40, 20, 'DELIVERED'),
#  (955, 1193, 40, 23, 'DELIVERED'),
#  (956, 1194, 40, 20, 'DELIVERED'),
#  (957, 1196, 40, 43, 'DELIVERED'),
#  (958, 1197, 40, 31, 'DELIVERED'),
#  (959, 1198, 40, 55, 'DELIVERED'),
#  (960, 1199, 40, 20, 'DELIVERED'),
#  (961, 1200, 40, 22, 'DELIVERED'),
#  (962, 1201, 40, 40, 'DELIVERED'),
#  (963, 1203, 40, 22, 'DELIVERED'),
#  (964, 1204, 40, 52, 'DELIVERED'),
#  (965, 1205, 40, 39, 'DELIVERED'),
#  (966, 1206, 40, 56, 'DELIVERED'),
#  (967, 1207, 40, 33, 'DELIVERED'),
#  (968, 1208, 40, 38, 'DELIVERED'),
#  (969, 1209, 40, 51, 'DELIVERED'),
#  (970, 1210, 40, 47, 'DELIVERED'),
#  (971, 1211, 40, 51, 'DELIVERED'),
#  (972, 1212, 40, 45, 'DELIVERED'),
#  (973, 1213, 40, 53, 'DELIVERED'),
#  (974, 1214, 40, 55, 'DELIVERED'),
#  (975, 1215, 40, 23, 'DELIVERED'),
#  (976, 1216, 40, 58, 'DELIVERED'),
#  (977, 1217, 40, 24, 'DELIVERED'),
#  (978, 1218, 40, 48, 'DELIVERED'),
#  (979, 1219, 40, 46, 'DELIVERED'),
#  (980, 1220, 40, 22, 'DELIVERED'),
#  (981, 1221, 40, 47, 'DELIVERED'),
#  (982, 1222, 40, 59, 'DELIVERED'),
#  (983, 1224, 40, 58, 'DELIVERED'),
#  (984, 1225, 40, 47, 'DELIVERED'),
#  (985, 1226, 40, 23, 'DELIVERED'),
#  (986, 1227, 40, 34, 'DELIVERED'),
#  (987, 1228, 40, 26, 'DELIVERED'),
#  (988, 1229, 40, 40, 'DELIVERED'),
#  (989, 1230, 40, 54, 'DELIVERED'),
#  (990, 1231, 40, 45, 'DELIVERED'),
#  (991, 1232, 40, 25, 'DELIVERED'),
#  (992, 1233, 40, 29, 'DELIVERED'),
#  (993, 1236, 40, 42, 'DELIVERED'),
#  (994, 1237, 40, 38, 'DELIVERED'),
#  (995, 1238, 40, 31, 'DELIVERED'),
#  (996, 1239, 40, 57, 'DELIVERED'),
#  (997, 1240, 40, 41, 'DELIVERED'),
#  (998, 1241, 40, 36, 'DELIVERED'),
#  (999, 1242, 40, 37, 'DELIVERED'),
#  (1000, 1243, 40, 33, 'DELIVERED'),
#  (1001, 1244, 40, 53, 'DELIVERED'),
#  (1002, 1245, 40, 45, 'DELIVERED'),
#  ...]

# %% [markdown]
# ## Project Overview: Swiggy End-to-End SQL Data Analysis System
#
# This project simulates a real-world **Swiggy-like food delivery platform** with the goal of performing **end-to-end SQL data analysis** on user orders, restaurant performance, and delivery efficiency.
#
# The focus of this project is **data generation, database design, and analysis**, not building a full production app.
#
# ---
#
# ## Frontend Simulation (Data Source)
#
# A Swiggy-style frontend UI was generated using AI to simulate realistic user behavior such as:
# - Browsing restaurants
# - Selecting food items
# - Adding items to cart
# - Placing an order
#
# The frontend is used **only as a data generator**, mimicking how users interact with a food delivery platform.
#
# No authentication, payment, or personal user details were implemented, as they are not required for data analysis.
#
# ---
#
# ##  Database Design (Schema Creation)
#
# A dedicated MySQL database (`swiggy_da`) was created with a **normalized relational schema** to store transactional data.
#
# The following tables were designed with proper **primary keys and foreign key constraints**:
#
# - `users` – stores user location data
# - `restaurants` – restaurant metadata
# - `menu_items` – food items linked to restaurants
# - `orders` – order-level details
# - `order_items` – items within each order
# - `deliveries` – delivery time and ETA data
# - `reviews` – post-delivery ratings
#
# Foreign keys were intentionally enforced to maintain **data integrity**, similar to real production systems.
#
# ---
#
# ##  Backend Integration (Flask API)
#
# A lightweight backend was built using **Flask** to act as an API layer between the frontend and the database.
#
# Key responsibilities of the backend:
# - Receive order data via POST requests
# - Insert orders and order items into MySQL
# - Simulate delivery time (expected vs actual)
# - Enforce database constraints during insertion
#
# This step ensures that all data entering the database follows a **realistic ingestion pipeline**.
#
# ---
#
# ## Initial Data Setup
#
# Before placing orders, required parent records were inserted manually:
# - A sample user was added to the `users` table
# - A restaurant was added to the `restaurants` table
# - Menu items were added to the `menu_items` table
#
# This was necessary because foreign key constraints require parent records to exist before inserting child records.
#
# ---
#
# ##  Order Simulation (End-to-End Flow)
#
# A POST request was sent to the Flask API simulating a real user placing an order:
# - User selects a restaurant
# - Chooses food items
# - Confirms the order
#
# The backend successfully:
# - Created a new record in `orders`
# - Inserted corresponding rows in `order_items`
# - Generated delivery metrics in `deliveries`
#
# The API returned a success response, confirming the order was stored correctly.
#
# ---
#
# ##  Verification & Data Integrity Check
#
# After the API call, SQL queries were executed to verify:
# - Orders were correctly stored
# - Items were linked to the order
# - Delivery information was recorded
# - All foreign key relationships were preserved
#
# This confirms that the **entire pipeline works end-to-end**.
#
# ---
#
#
# This setup closely mirrors how data flows in real food delivery platforms and forms a strong foundation for SQL-based data analysis and business insights.
